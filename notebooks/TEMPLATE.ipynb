# %% [markdown]
# # A title that names the economic object
#
# Open with the situation the reader needs to understand and give the main answer in ordinary economic language. State the strongest limitation where it first matters. Do not lead with internal status labels, solution methods, or a list of what the notebook will eventually do.

# %% [markdown]
# ## Begin from actors, timing, and the comparison
#
# Explain who chooses, what is inherited, which shock or policy changes, and what is held fixed. Introduce $(S_0,M_0)$ only if the inherited physical and financial states, promises, multipliers, or commitments matter for the comparison.
#
# Define a mathematical object in words before compressing it into a vector, transformation, or operator.

# %% [markdown]
# ## Show the equation that carries the economics
#
# Give each display one job. Identify whether it is a definition, identity, first-order condition, conditional characterization, approximation, or computed relation. Explain the substitution, projection, cancellation, or boundary condition that produces the conclusion; do not read the symbols aloud.
#
# State existence, uniqueness, verification, and approximation claims only when their support establishes those exact objects.

# %% [markdown]
# ## Introduce the calculation
#
# Before the next code cell, say what economic quantity it produces, why the calculation is needed, and how the reader should interpret the output. Use a thin call to pinned public code or a frozen, hash-identified export.

# %%
from pathlib import Path

repository_root = Path.cwd().resolve()
repository_root
# Out:
# PosixPath('/Users/nathanbarnard/Documents/tai-public-finance-home/notebooks')

# %% [markdown]
# ## Interpret the result where the reader sees it
#
# Explain the force that drives the result, the opposing force, and the benchmark or boundary at which the conclusion changes. Distinguish analytical implications, computed outputs, illustrations, and diagnostics without repeating the full audit taxonomy in every paragraph.

# %% [markdown]
# ## End with the exact boundary and reproduction route
#
# Say what the notebook establishes and the most important thing it does not. Then record the upstream repository, full commit, environment or lockfile, computation and specification identifiers, run or data provenance, and exact reproduction command.
