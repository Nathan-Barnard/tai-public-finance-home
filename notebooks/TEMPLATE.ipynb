# %% [markdown]
# # Notebook title
#
# State the reader's question and why it matters for the paper.

# %% [markdown]
# ## Answer in brief
#
# State what the notebook establishes, the comparison, and the main limitation. Distinguish an analytical result, computed result, illustration, and provisional diagnostic.

# %% [markdown]
# ## Model and comparison
#
# Define the actors, inherited state `(S_0, M_0)`, controls, timing, closure, units, and what is held fixed. Link the exact public source where possible.

# %% [markdown]
# ## Computational route
#
# Explain what the next code cell checks or calculates, why this method is appropriate, and how its output should be interpreted. Replace the placeholder with a thin call to pinned upstream code or a frozen export.

# %%
from pathlib import Path

repository_root = Path.cwd().resolve()
repository_root

# %% [markdown]
# ## Diagnostics
#
# Report the checks that matter for the displayed use: economic residuals, feasibility, boundaries, convergence or sensitivity, and the closest transparent benchmark.

# %% [markdown]
# ## Economic interpretation
#
# Explain the mechanism, the main opposing force, what the result rules in or out, and the assumption or uncertainty most capable of changing the conclusion.

# %% [markdown]
# ## Reproduce and trace
#
# Record the upstream repository, full commit, environment or lockfile, computation/specification identifiers, run or data provenance, and the exact reproduction command.
